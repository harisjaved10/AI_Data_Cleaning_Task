# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Reading File

# %%
data = pd.read_csv("ExtraTask.csv")
data.head(20)
# Out:
#     Unnamed: 0  MaskedID        date pocType  numericvalue  unitname  \
# 0            0    100005  2011-09-20  Weight          82.5  kilogram
# 1            1    100005  2011-09-20  Weight          82.5  kilogram
# 2            2    100005  2011-11-01  Weight          81.8  kilogram
# 3            3    100005  2011-11-01  Weight          81.8  kilogram
# 4            4    100005  2012-02-14  Weight          81.2  kilogram
# 5            5    100005  2012-02-14  Weight          81.2  kilogram
# 6            6    100005  2012-05-15  Weight          81.8  kilogram
# 7            7    100005  2012-05-15  Weight          81.8  kilogram
# 8            8    100005  2012-06-19  Weight          81.1  kilogram
# 9            9    100005  2012-10-09  Weight          79.2  kilogram
# 10          10    100006  2011-07-11  Weight          91.3  kilogram
# 11          11    100006  2011-08-08  Weight          90.0  kilogram
# 12          12    100006  2011-08-22  Weight          89.7  kilogram
# 13          13    100006  2011-08-22  Weight          89.7  kilogram
# 14          14    100006  2011-10-05  Weight          90.3  kilogram
# 15          15    100006  2011-10-05  Weight          90.3  kilogram
# 16          16    100006  2011-10-05  Weight          90.3  kilogram
# 17          17    100006  2011-11-28  Weight          90.2  kilogram
# 18          18    100006  2011-11-28  Weight          90.2  kilogram
# 19          19    100006  2011-12-19  Weight          92.1  kilogram
#
#    unitindice
# 0          kg
# 1          kg
# 2          kg
# 3          kg
# 4          kg
# 5          kg
# 6          kg
# 7          kg
# 8          kg
# 9          kg
# 10         kg
# 11         kg
# 12         kg
# 13         kg
# 14         kg
# 15         kg
# 16         kg
# 17         kg
# 18         kg
# 19         kg

# %% [markdown]
# # Dropping 'unitname' and 'unitindice' columns

# %%
new_data = data.drop(['unitname', 'unitindice'], axis=1)
new_data.head(30)
# Out:
#     Unnamed: 0  MaskedID        date pocType  numericvalue
# 0            0    100005  2011-09-20  Weight          82.5
# 1            1    100005  2011-09-20  Weight          82.5
# 2            2    100005  2011-11-01  Weight          81.8
# 3            3    100005  2011-11-01  Weight          81.8
# 4            4    100005  2012-02-14  Weight          81.2
# 5            5    100005  2012-02-14  Weight          81.2
# 6            6    100005  2012-05-15  Weight          81.8
# 7            7    100005  2012-05-15  Weight          81.8
# 8            8    100005  2012-06-19  Weight          81.1
# 9            9    100005  2012-10-09  Weight          79.2
# 10          10    100006  2011-07-11  Weight          91.3
# 11          11    100006  2011-08-08  Weight          90.0
# 12          12    100006  2011-08-22  Weight          89.7
# 13          13    100006  2011-08-22  Weight          89.7
# 14          14    100006  2011-10-05  Weight          90.3
# 15          15    100006  2011-10-05  Weight          90.3
# 16          16    100006  2011-10-05  Weight          90.3
# 17          17    100006  2011-11-28  Weight          90.2
# 18          18    100006  2011-11-28  Weight          90.2
# 19          19    100006  2011-12-19  Weight          92.1
# 20          20    100012  2011-08-15  Weight          72.0
# 21          21    100012  2011-08-15  Weight          72.0
# 22          22    100012  2011-08-16  Weight          72.0
# 23          23    100012  2011-09-29  Weight          71.7
# 24          24    100012  2011-11-22  Weight          71.0
# 25          25    100012  2011-12-26  Weight          70.0
# 26          26    100012  2012-02-28  Weight          73.0
# 27          27    100012  2012-02-28  Weight          73.0
# 28          28    100012  2012-03-26  Weight          72.4
# 29          29    100012  2012-03-26  Weight          72.4

# %% [markdown]
# # Checking unique values in column 'pocType'

# %%
unique = data.pocType.unique().tolist()
unique
# Out:
# ['Weight',
#  'Heart rate',
#  'Height',
#  'Waist circumference',
#  'BMI',
#  '[POC] Hemoglobin A1c']

# %% [markdown]
# # Selecting co-responding row data w.r.t unique values in column 'pocType'

# %%
weight = new_data.loc[new_data['pocType'] == 'Weight', 'numericvalue']
weight
# Out:
# 0      82.5
# 1      82.5
# 2      81.8
# 3      81.8
# 4      81.2
#        ...
# 995    71.0
# 996    71.0
# 997    70.0
# 998    70.0
# 999    70.0
# Name: numericvalue, Length: 1000, dtype: float64

# %%
heart_rate = new_data.loc[new_data['pocType'] == 'Heart rate', 'numericvalue']
heart_rate
# Out:
# 1000    80.0
# 1001    80.0
# 1002    76.0
# 1003    76.0
# 1004    79.0
#         ...
# 1995    85.0
# 1996    85.0
# 1997    90.0
# 1998    90.0
# 1999    50.0
# Name: numericvalue, Length: 1000, dtype: float64

# %%
height = new_data.loc[new_data['pocType'] == 'Height', 'numericvalue']
height
# Out:
# 2000    154.0
# 2001    154.0
# 2002    154.0
# 2003    154.0
# 2004    154.0
#         ...
# 2995    161.0
# 2996    161.0
# 2997    161.0
# 2998    161.0
# 2999    162.0
# Name: numericvalue, Length: 1000, dtype: float64

# %%
bmi = new_data.loc[new_data['pocType'] == 'BMI', 'numericvalue']
bmi
# Out:
# 4000    34.79
# 4001    34.79
# 4002    34.20
# 4003    33.40
# 4004    33.40
#         ...
# 4995    25.91
# 4996    35.38
# 4997    24.86
# 4998    24.86
# 4999    25.21
# Name: numericvalue, Length: 1000, dtype: float64

# %%
waist_circumference = new_data.loc[new_data['pocType'] == 'Waist Circumference', 'numericvalue']
waist_circumference
# Out:
# Series([], Name: numericvalue, dtype: float64)

# %%
hemoglobin = new_data.loc[new_data['pocType'] == '[POC] Hemoglobin A1c', 'numericvalue']
hemoglobin
# Out:
# 5000    6.2
# 5001    6.2
# 5002    7.8
# 5003    7.8
# 5004    7.8
#        ...
# 5995    7.8
# 5996    7.2
# 5997    7.8
# 5998    7.8
# 5999    8.1
# Name: numericvalue, Length: 1000, dtype: float64

# %% [markdown]
# # Adding new columns

# %%
new_data["Weight"] = weight
new_data["Heart Rate"] = heart_rate
new_data["Height"] = height
new_data["BMI"] = bmi
new_data["Hemoglobin A1c"] = hemoglobin
new_data["Waist Circumference"] = waist_circumference

new_data
# Out:
#       Unnamed: 0  MaskedID        date               pocType  numericvalue  \
# 0              0    100005  2011-09-20                Weight          82.5
# 1              1    100005  2011-09-20                Weight          82.5
# 2              2    100005  2011-11-01                Weight          81.8
# 3              3    100005  2011-11-01                Weight          81.8
# 4              4    100005  2012-02-14                Weight          81.2
# ...          ...       ...         ...                   ...           ...
# 5995        5995    115763  2018-02-13  [POC] Hemoglobin A1c           7.8
# 5996        5996    123412  2018-02-13  [POC] Hemoglobin A1c           7.2
# 5997        5997    118752  2018-02-13  [POC] Hemoglobin A1c           7.8
# 5998        5998    118752  2018-02-13  [POC] Hemoglobin A1c           7.8
# 5999        5999    119376  2018-02-13  [POC] Hemoglobin A1c           8.1
#
#       Weight  Heart Rate  Height  BMI  Hemoglobin A1c  Waist Circumference
# 0       82.5         NaN     NaN  NaN             NaN                  NaN
# 1       82.5         NaN     NaN  NaN             NaN                  NaN
# 2       81.8         NaN     NaN  NaN             NaN                  NaN
# 3       81.8         NaN     NaN  NaN             NaN                  NaN
# 4       81.2         NaN     NaN  NaN             NaN                  NaN
# ...      ...         ...     ...  ...             ...                  ...
# 5995     NaN         NaN     NaN  NaN             7.8                  NaN
# 5996     NaN         NaN     NaN  NaN             7.2                  NaN
# 5997     NaN         NaN     NaN  NaN             7.8                  NaN
# 5998     NaN         NaN     NaN  NaN             7.8                  NaN
# 5999     NaN         NaN     NaN  NaN             8.1                  NaN
#
# [6000 rows x 11 columns]

# %% [markdown]
# # Dropping date, pocType, and numericvalue columns

# %%
new_data = new_data.drop(['date'], axis=1)
new_data = new_data.drop(['pocType'], axis=1)
new_data = new_data.drop(['numericvalue'], axis=1)

new_data
# Out:
#       Unnamed: 0  MaskedID  Weight  Heart Rate  Height  BMI  Hemoglobin A1c  \
# 0              0    100005    82.5         NaN     NaN  NaN             NaN
# 1              1    100005    82.5         NaN     NaN  NaN             NaN
# 2              2    100005    81.8         NaN     NaN  NaN             NaN
# 3              3    100005    81.8         NaN     NaN  NaN             NaN
# 4              4    100005    81.2         NaN     NaN  NaN             NaN
# ...          ...       ...     ...         ...     ...  ...             ...
# 5995        5995    115763     NaN         NaN     NaN  NaN             7.8
# 5996        5996    123412     NaN         NaN     NaN  NaN             7.2
# 5997        5997    118752     NaN         NaN     NaN  NaN             7.8
# 5998        5998    118752     NaN         NaN     NaN  NaN             7.8
# 5999        5999    119376     NaN         NaN     NaN  NaN             8.1
#
#       Waist Circumference
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 5995                  NaN
# 5996                  NaN
# 5997                  NaN
# 5998                  NaN
# 5999                  NaN
#
# [6000 rows x 8 columns]

# %% [markdown]
# # Replacing Nan cells with their mean values

# %%
new_data['Weight'].fillna((new_data['Weight'].mean()), inplace=True)
new_data['Heart Rate'].fillna((new_data['Heart Rate'].mean()), inplace=True)
new_data['Height'].fillna((new_data['Height'].mean()), inplace=True)
new_data['BMI'].fillna((new_data['BMI'].mean()), inplace=True)
new_data['Hemoglobin A1c'].fillna((new_data['Hemoglobin A1c'].mean()), inplace=True)
new_data['Waist Circumference'].fillna((new_data['Waist Circumference'].mean()), inplace=True)


new_data
# Out:
#       Unnamed: 0  MaskedID   Weight  Heart Rate    Height       BMI  \
# 0              0    100005  82.5000      76.553  161.5827  32.37408
# 1              1    100005  82.5000      76.553  161.5827  32.37408
# 2              2    100005  81.8000      76.553  161.5827  32.37408
# 3              3    100005  81.8000      76.553  161.5827  32.37408
# 4              4    100005  81.2000      76.553  161.5827  32.37408
# ...          ...       ...      ...         ...       ...       ...
# 5995        5995    115763  83.7471      76.553  161.5827  32.37408
# 5996        5996    123412  83.7471      76.553  161.5827  32.37408
# 5997        5997    118752  83.7471      76.553  161.5827  32.37408
# 5998        5998    118752  83.7471      76.553  161.5827  32.37408
# 5999        5999    119376  83.7471      76.553  161.5827  32.37408
#
#       Hemoglobin A1c  Waist Circumference
# 0            8.46871                  NaN
# 1            8.46871                  NaN
# 2            8.46871                  NaN
# 3            8.46871                  NaN
# 4            8.46871                  NaN
# ...              ...                  ...
# 5995         7.80000                  NaN
# 5996         7.20000                  NaN
# 5997         7.80000                  NaN
# 5998         7.80000                  NaN
# 5999         8.10000                  NaN
#
# [6000 rows x 8 columns]
